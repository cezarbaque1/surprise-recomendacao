# %%
from conn.apis import *
import pandas as pd

retorno = get_all_respostas()
getDf = pd.DataFrame(retorno)
getDf.head()
# Out:
#            1          2                                 3  \
# 0  Masculino      Praia  Já acertou muita coisa sobre mim
# 1  Masculino   Montanha  Já acertou muita coisa sobre mim
# 2   Feminino      Praia  Já acertou muita coisa sobre mim
# 3   Feminino  Tanto faz  Já acertou muita coisa sobre mim
# 4  Masculino  Tanto faz       Fiz meu mapa astral uma vez
#
#                      4                                                  5  \
# 0        Cineminha top     Fico observando para ver se não conheço alguém
# 1        Cineminha top  Depende do meu humor, as vezes fico na minha e...
# 2  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 3        Ficar em casa  Depende do meu humor, as vezes fico na minha e...
# 4        Ficar em casa  Depende do meu humor, as vezes fico na minha e...
#
#       updatedAt                                           produtos  \
# 0  1.722484e+09  [{'produto': 'CJ2297063', 'response': 'Mais ou...
# 1  1.722563e+09  [{'produto': 'DN4181010', 'response': 'Não Gos...
# 2  1.722896e+09  [{'produto': 'DX1023716', 'response': 'Mais ou...
# 3  1.722896e+09  [{'produto': 'FB5372100', 'response': 'Mais ou...
# 4  1.722724e+09  [{'produto': 'DV4352100', 'response': 'Não Gos...
#
#        idResposta
# 0  20240801005444
# 1  20240802014246
# 2  20240805222156
# 3  20240805222519
# 4  20240803224119

# %%
print('Número de Respostas: ' + str(len(getDf)))
# Out:
# Número de Respostas: 69

# %%
df = getDf.explode('produtos')
print('Número de Produtos Avaliados: ' + str(len(df)))
df.head()
# Out:
# Número de Produtos Avaliados: 414
#            1      2                                 3              4  \
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
#
#                                                 5     updatedAt  \
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
#
#                                             produtos      idResposta
# 0  {'produto': 'CJ2297063', 'response': 'Mais ou ...  20240801005444
# 0  {'produto': 'DD3242600', 'response': 'Mais ou ...  20240801005444
# 0  {'produto': 'FD3031532', 'response': 'Mais ou ...  20240801005444
# 0      {'produto': 'DX5074010', 'response': 'Amei!'}  20240801005444
# 0      {'produto': 'FB9660001', 'response': 'Amei!'}  20240801005444

# %%
df['produtosSeparado'] = df['produtos'].apply(lambda x:x['produto'])
df['respostaProduto'] = df['produtos'].apply(lambda x:x['response'])
df = df[df['respostaProduto'] != 'Não Gostei' ]
df.head()
# Out:
#            1      2                                 3              4  \
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
# 0  Masculino  Praia  Já acertou muita coisa sobre mim  Cineminha top
#
#                                                 5     updatedAt  \
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
# 0  Fico observando para ver se não conheço alguém  1.722484e+09
#
#                                             produtos      idResposta  \
# 0  {'produto': 'CJ2297063', 'response': 'Mais ou ...  20240801005444
# 0  {'produto': 'DD3242600', 'response': 'Mais ou ...  20240801005444
# 0  {'produto': 'FD3031532', 'response': 'Mais ou ...  20240801005444
# 0      {'produto': 'DX5074010', 'response': 'Amei!'}  20240801005444
# 0      {'produto': 'FB9660001', 'response': 'Amei!'}  20240801005444
#
#   produtosSeparado respostaProduto
# 0        CJ2297063   Mais ou Menos
# 0        DD3242600   Mais ou Menos
# 0        FD3031532   Mais ou Menos
# 0        DX5074010           Amei!
# 0        FB9660001           Amei!

# %%
gostei_df = df.groupby('respostaProduto').agg(
    count=('respostaProduto', 'count')
).sort_values(by='count', ascending=False).reset_index()
gostei_df
# Out:
#   respostaProduto  count
# 0   Mais ou Menos    110
# 1           Amei!     98

# %%
grouped_df = df.groupby('produtosSeparado').agg(
    count=('produtosSeparado', 'count')
).sort_values(by='count', ascending=False).reset_index()
grouped_df.head()
# Out:
#   produtosSeparado  count
# 0        DM6419010      4
# 1        FB5636376      4
# 2        FB7351410      4
# 3        FB5372100      4
# 4        FD3067476      4

# %%
countdf = grouped_df
countdf['contagem'] = countdf['count']
countdf = countdf[['contagem', 'produtosSeparado']]
countdf = grouped_df.groupby('contagem').agg(count=('produtosSeparado', 'count')
).sort_values(by='count', ascending=False).reset_index()
countdf
# Out:
#    contagem  count
# 0         1     88
# 1         2     33
# 2         3     10
# 3         4      6

# %%
dfAjustado = df[df['respostaProduto'] != 'Não Gostei' ] #Filtras tudo que não é "Não Gostei"

#Filtras produtos que tiveram duas respostas ou mais
dfAjustado = dfAjustado.merge(grouped_df,how='left', on='produtosSeparado') 
dfAjustado = dfAjustado[dfAjustado['count'] > 1]

#Duplicar linhas que foram selecionadas como "Amei"
dfAmei = dfAjustado[dfAjustado['respostaProduto'] != 'Amei!' ] 
dfAjustado = pd.concat([dfAjustado, dfAmei], ignore_index=True).reset_index()

#Resultado
print(len(dfAjustado))
dfAjustado.head()
# Out:
# 186
#    index          1      2                                 3  \
# 0      0  Masculino  Praia  Já acertou muita coisa sobre mim
# 1      1  Masculino  Praia  Já acertou muita coisa sobre mim
# 2      2  Masculino  Praia  Já acertou muita coisa sobre mim
# 3      3   Feminino  Praia  Já acertou muita coisa sobre mim
# 4      4   Feminino  Praia  Já acertou muita coisa sobre mim
#
#                      4                                               5  \
# 0        Cineminha top  Fico observando para ver se não conheço alguém
# 1        Cineminha top  Fico observando para ver se não conheço alguém
# 2        Cineminha top  Fico observando para ver se não conheço alguém
# 3  Um Barzinho de leve  Fico observando para ver se não conheço alguém
# 4  Um Barzinho de leve  Fico observando para ver se não conheço alguém
#
#       updatedAt                                           produtos  \
# 0  1.722484e+09  {'produto': 'DD3242600', 'response': 'Mais ou ...
# 1  1.722484e+09      {'produto': 'DX5074010', 'response': 'Amei!'}
# 2  1.722484e+09      {'produto': 'FB9660001', 'response': 'Amei!'}
# 3  1.722896e+09  {'produto': 'DX1023716', 'response': 'Mais ou ...
# 4  1.722896e+09      {'produto': 'FN0891406', 'response': 'Amei!'}
#
#        idResposta produtosSeparado respostaProduto  count  contagem
# 0  20240801005444        DD3242600   Mais ou Menos      2         2
# 1  20240801005444        DX5074010           Amei!      2         2
# 2  20240801005444        FB9660001           Amei!      2         2
# 3  20240805222156        DX1023716   Mais ou Menos      3         3
# 4  20240805222156        FN0891406           Amei!      3         3

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import numpy as np

# %%
#Separa variaveis sucessoras e predecessoras
x = dfAjustado[['1','2','3','4','5']]
y = dfAjustado['produtosSeparado']

#transforma o y em um array
y = y.to_numpy()

# Dividir os dados em treino e teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2, random_state=42)

print(len(x_treino))
print(len(x_teste))
x_treino.head()
# Out:
# 148
# 38
#              1          2                                                  3  \
# 123   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 135   Feminino      Praia  Não acredito que a posição dos planetas influe...
# 150   Feminino      Praia  Não acredito que a posição dos planetas influe...
# 31    Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 12   Masculino      Praia                   Já acertou muita coisa sobre mim
#
#                        4                                                  5
# 123        Ficar em casa  Depende do meu humor, as vezes fico na minha e...
# 135  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 150        Ficar em casa     Fico observando para ver se não conheço alguém
# 31   Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 12         Cineminha top     Fico observando para ver se não conheço alguém

# %%
#Criar a Pipeline
encoder = OneHotEncoder()
modelo = GaussianNB()

pipeline = Pipeline([
    ('encoder', ColumnTransformer([('encoder', encoder, ['1','2','3','4','5']) ] ) ),
    ('modelo', modelo)
])

# %%
pipeline.fit(x_treino, y_treino)
# Out:
# Pipeline(steps=[('encoder',
#                  ColumnTransformer(transformers=[('encoder', OneHotEncoder(),
#                                                   ['1', '2', '3', '4', '5'])])),
#                 ('modelo', GaussianNB())])

# %%
predictions = pipeline.predict(x_teste)
print(predictions)
# Out:
# ['FD3067476' 'FZ7555100' 'DH9552019' 'DH9779663' 'DH9779663' 'DN4181309'
#  'FD4109001' 'DQ5636618' 'FD4109001' 'BV6708100' 'CZ9062010' 'FZ7555100'
#  'DR5077729' 'FD4109001' 'DQ5415126' 'FJ5479410' 'DX1023716' 'DZ6293349'
#  'CZ9062010' 'DX5074010' 'FZ7555100' 'DR5077729' 'FJ5479410' 'DH6863225'
#  'DQ5415126' 'FJ5479410' 'DN4181309' 'CZ9062010' 'DX5074010' 'FZ7555100'
#  'DH9779663' 'FB5628324' 'DZ6293349' 'DC7210010' 'DH6863225' 'DQ5415126'
#  'DQ5415126' 'DZ6293349']

# %%
accuracy = pipeline.score(x_teste, y_teste)
print(f"Acurácia da pipeline: {accuracy}")
# Out:
# Acurácia da pipeline: 0.2631578947368421

# %%
x_teste['idProduto'] = predictions
x_teste['idProdutoOriginal'] = y_teste
x_teste_prod = x_teste
x_teste_prod.head()
# Out:
#              1          2                                                  3  \
# 113  Masculino   Montanha  Não acredito que a posição dos planetas influe...
# 164   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 169   Feminino   Montanha                   Já acertou muita coisa sobre mim
# 101  Masculino      Praia  Não acredito que a posição dos planetas influe...
# 100  Masculino      Praia  Não acredito que a posição dos planetas influe...
#
#                        4                                                  5  \
# 113        Cineminha top  Depende do meu humor, as vezes fico na minha e...
# 164  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 169  Um Barzinho de leve      Vejo se tem alguém interessante para conhecer
# 101  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 100  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
#
#      idProduto idProdutoOriginal
# 113  FD3067476         FD3067476
# 164  FZ7555100         FB5372100
# 169  DH9552019         FB7351410
# 101  DH9779663         DC7485100
# 100  DH9779663         FB5122133

# %%
produtos = pd.DataFrame(get_all_products())
nomeProdutos = produtos[['idProduto','name','firstName']]
nomeProdutos.head()
# Out:
#    idProduto                                               name firstName
# 0  DJ7780078  Camisa Nike PSG II 2022/23 Torcedora Pro Feminina    Camisa
# 1  FB4095457                           Top Jordan Indy Feminino       Top
# 2  DQ8917536                 Legging Nike Yoga Dri-FIT Infantil   Legging
# 3  943826501            Sandália Nike Sunray Protect 2 Infantil  Sandália
# 4  DD4921609            Camiseta Nike Dri-FIT One Luxe Feminina  Camiseta

# %%
dfAnalise = pd.merge(left=x_teste, right=nomeProdutos, on='idProduto', how='left')
dfAnalise.head(10)
# Out:
#            1          2                                                  3  \
# 0  Masculino   Montanha  Não acredito que a posição dos planetas influe...
# 1   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 2   Feminino   Montanha                   Já acertou muita coisa sobre mim
# 3  Masculino      Praia  Não acredito que a posição dos planetas influe...
# 4  Masculino      Praia  Não acredito que a posição dos planetas influe...
# 5  Masculino      Praia                   Já acertou muita coisa sobre mim
# 6  Masculino  Tanto faz                   Já acertou muita coisa sobre mim
# 7   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 8  Masculino  Tanto faz                   Já acertou muita coisa sobre mim
# 9   Feminino   Montanha  Não acredito que a posição dos planetas influe...
#
#                      4                                                  5  \
# 0        Cineminha top  Depende do meu humor, as vezes fico na minha e...
# 1  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 2  Um Barzinho de leve      Vejo se tem alguém interessante para conhecer
# 3  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 4  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 5        Cineminha top     Fico observando para ver se não conheço alguém
# 6        Ficar em casa      Vejo se tem alguém interessante para conhecer
# 7  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 8        Ficar em casa      Vejo se tem alguém interessante para conhecer
# 9  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
#
#    idProduto idProdutoOriginal                                        name  \
# 0  FD3067476         FD3067476           Agasalho Nike Sportswear Infantil
# 1  FZ7555100         FB5372100               Bola Nike Pitch Train Futebol
# 2  DH9552019         FB7351410    Saia Nike Court Dri-FIT Victory Feminina
# 3  DH9779663         DC7485100    Saia Nike Court Dri-FIT Victory Feminina
# 4  DH9779663         FB5122133    Saia Nike Court Dri-FIT Victory Feminina
# 5  DN4181309         DX1023716  Plus Size - Top Nike Dri-FIT Indy Feminino
# 6  FD4109001         FD4109001      Chinelo Nike Offcourt Easyon Masculino
# 7  DQ5636618         DV4352100                    Legging Nike Go Feminina
# 8  FD4109001         DM6419010      Chinelo Nike Offcourt Easyon Masculino
# 9  BV6708100         BV6708100               Camisa Nike Dri-Fit Uniformes
#
#   firstName
# 0  Agasalho
# 1      Bola
# 2      Saia
# 3      Saia
# 4      Saia
# 5      Plus
# 6   Chinelo
# 7   Legging
# 8   Chinelo
# 9    Camisa

# %%
dfAnalise = pd.merge(left=x_teste, right=nomeProdutos, on='idProduto', how='left')
dfAnalise[dfAnalise['idProduto'] != dfAnalise['idProdutoOriginal']]
# Out:
#             1          2                                                  3  \
# 1    Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 2    Feminino   Montanha                   Já acertou muita coisa sobre mim
# 3   Masculino      Praia  Não acredito que a posição dos planetas influe...
# 4   Masculino      Praia  Não acredito que a posição dos planetas influe...
# 5   Masculino      Praia                   Já acertou muita coisa sobre mim
# 7    Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 8   Masculino  Tanto faz                   Já acertou muita coisa sobre mim
# 10   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 11   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 13  Masculino  Tanto faz                   Já acertou muita coisa sobre mim
# 14  Masculino      Praia  Não acredito que a posição dos planetas influe...
# 17   Feminino      Praia                   Já acertou muita coisa sobre mim
# 18   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 19   Feminino      Praia                        Fiz meu mapa astral uma vez
# 20   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 22  Masculino  Tanto faz                        Fiz meu mapa astral uma vez
# 23   Feminino      Praia                   Já acertou muita coisa sobre mim
# 24  Masculino      Praia  Não acredito que a posição dos planetas influe...
# 26  Masculino      Praia                   Já acertou muita coisa sobre mim
# 27   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 28   Feminino      Praia                        Fiz meu mapa astral uma vez
# 29   Feminino  Tanto faz                   Já acertou muita coisa sobre mim
# 30  Masculino      Praia  Não acredito que a posição dos planetas influe...
# 32   Feminino      Praia                   Já acertou muita coisa sobre mim
# 33  Masculino  Tanto faz                        Fiz meu mapa astral uma vez
# 34   Feminino      Praia                   Já acertou muita coisa sobre mim
# 36  Masculino      Praia  Não acredito que a posição dos planetas influe...
# 37   Feminino      Praia                   Já acertou muita coisa sobre mim
#
#                       4                                                  5  \
# 1   Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 2   Um Barzinho de leve      Vejo se tem alguém interessante para conhecer
# 3   Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 4   Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 5         Cineminha top     Fico observando para ver se não conheço alguém
# 7   Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 8         Ficar em casa      Vejo se tem alguém interessante para conhecer
# 10        Cineminha top  Depende do meu humor, as vezes fico na minha e...
# 11  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 13        Ficar em casa      Vejo se tem alguém interessante para conhecer
# 14  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 17        Cineminha top  Depende do meu humor, as vezes fico na minha e...
# 18        Cineminha top  Depende do meu humor, as vezes fico na minha e...
# 19  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 20  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 22        Ficar em casa  Depende do meu humor, as vezes fico na minha e...
# 23  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 24  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 26        Cineminha top     Fico observando para ver se não conheço alguém
# 27        Cineminha top  Depende do meu humor, as vezes fico na minha e...
# 28  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 29  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 30  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 32        Cineminha top  Depende do meu humor, as vezes fico na minha e...
# 33  Um Barzinho de leve      Vejo se tem alguém interessante para conhecer
# 34  Um Barzinho de leve  Depende do meu humor, as vezes fico na minha e...
# 36  Um Barzinho de leve     Fico observando para ver se não conheço alguém
# 37        Cineminha top  Depende do meu humor, as vezes fico na minha e...
#
#     idProduto idProdutoOriginal  \
# 1   FZ7555100         FB5372100
# 2   DH9552019         FB7351410
# 3   DH9779663         DC7485100
# 4   DH9779663         FB5122133
# 5   DN4181309         DX1023716
# 7   DQ5636618         DV4352100
# 8   FD4109001         DM6419010
# 10  CZ9062010         DH9779663
# 11  FZ7555100         FB9660001
# 13  FD4109001         FQ7079001
# 14  DQ5415126         DV9967010
# 17  DZ6293349         DJ9678010
# 18  CZ9062010         FD3067476
# 19  DX5074010         FN0891406
# 20  FZ7555100         FD3067476
# 22  FJ5479410         FB5636010
# 23  DH6863225         DC7210010
# 24  DQ5415126         FB7351410
# 26  DN4181309         FB5636376
# 27  CZ9062010         FV6603101
# 28  DX5074010         DZ6294266
# 29  FZ7555100         FD3067476
# 30  DH9779663         DX1404894
# 32  DZ6293349         DN4181309
# 33  DC7210010         BV6907463
# 34  DH6863225         DC7210010
# 36  DQ5415126         FB7351410
# 37  DZ6293349         DZ6294266
#
#                                               name firstName
# 1                    Bola Nike Pitch Train Futebol      Bola
# 2         Saia Nike Court Dri-FIT Victory Feminina      Saia
# 3         Saia Nike Court Dri-FIT Victory Feminina      Saia
# 4         Saia Nike Court Dri-FIT Victory Feminina      Saia
# 5       Plus Size - Top Nike Dri-FIT Indy Feminino      Plus
# 7                         Legging Nike Go Feminina   Legging
# 8           Chinelo Nike Offcourt Easyon Masculino   Chinelo
# 10        Shorts Nike Dri-FIT Challenger Masculino    Shorts
# 11                   Bola Nike Pitch Train Futebol      Bola
# 13          Chinelo Nike Offcourt Easyon Masculino   Chinelo
# 14     Blusão Nike Sportswear Club Fleece Feminino    Blusão
# 17                   Pochete Nike Heritage Unissex   Pochete
# 18        Shorts Nike Dri-FIT Challenger Masculino    Shorts
# 19  Meia Nike Everyday Essential (3 Pares) Unissex      Meia
# 20                   Bola Nike Pitch Train Futebol      Bola
# 22                               Women's Air Max 1   Women's
# 23                    Bolsa Nike Gym Club Feminina     Bolsa
# 24     Blusão Nike Sportswear Club Fleece Feminino    Blusão
# 26      Plus Size - Top Nike Dri-FIT Indy Feminino      Plus
# 27        Shorts Nike Dri-FIT Challenger Masculino    Shorts
# 28  Meia Nike Everyday Essential (3 Pares) Unissex      Meia
# 29                   Bola Nike Pitch Train Futebol      Bola
# 30        Saia Nike Court Dri-FIT Victory Feminina      Saia
# 32                   Pochete Nike Heritage Unissex   Pochete
# 33            Blusão Nike Sportswear Club Infantil    Blusão
# 34                    Bolsa Nike Gym Club Feminina     Bolsa
# 36     Blusão Nike Sportswear Club Fleece Feminino    Blusão
# 37                   Pochete Nike Heritage Unissex   Pochete

# %%
import joblib
import base64

pickle_file_path = 'modelo/predicao_surprise.pkl'
# Salvando o modelo
joblib.dump(pipeline, pickle_file_path)

def pickle_to_base64(pickle_file_path):
    with open(pickle_file_path, 'rb') as file:
        pickle_content = file.read()
        base64_content = base64.b64encode(pickle_content)
        base64_str = base64_content.decode('utf-8')
        return base64_str
    
base64File = pickle_to_base64(pickle_file_path)

# %%
resposta = post_predict(base64File)
resposta
# Out:
# []

# %%
predictBase64 = get_predict()
predictContent = base64.b64decode(predictBase64)

with open('modelo/predicao_surprise.pkl', 'wb') as file:
            file.write(predictContent)

# %%
pickle_file_path = 'modelo/predicao_surprise.pkl'
pipeline2 = joblib.load(pickle_file_path)

# %%
new_data = pd.DataFrame([{
    '1': 'Masculino',
    '2': 'Praia',
    '3': 'Já acertou muita coisa sobre mim',
    '4': 'Cineminha top',
    '5': 'Fico observando para ver se não conheço alguém'
}])

prediction = pipeline2.predict_proba(new_data)
top2_indices  = prediction[0].argsort()[-2:][::-1]
produtos_recomendados = pipeline2.classes_[top2_indices]
produtos_recomendados
# Out:
# array(['DN4181309', 'DD3242600'], dtype='<U9')
